# %%
import os
import numpy as np
import re

# --- GT mapping for conditions ---
CONDITION_GT = {
    'A': {'name': "Healthy rest", 'RR': 14,  'HR': 80},
    'B': {'name': "Healthy sleeping", 'RR': 12, 'HR': 60},
    'C': {'name': "Healthy agitated", 'RR': 20, 'HR': 110},
    'D': {'name': "Apnea", 'RR': 0, 'HR': 80},
    'E': {'name': "Asthma", 'RR': 22, 'HR': 90},
    'F': {'name': "Asthma attack", 'RR': 33, 'HR': 130},
    'G': {'name': "pneumothorax", 'RR': 30, 'HR': 120},
    'H': {'name': "Bradypnea", 'RR': 6, 'HR': 50},
    'I': {'name': "Cardiac arrest", 'RR': 16, 'HR': 160},
    'J': {'name': "ACS Chest Pain", 'RR': 18, 'HR': 104},
    'K': {'name': "Tachynpea Hyperventilation", 'RR': 30, 'HR': 125}
}

# --- 1. Filename Metadata Parser ---
def parse_iwr6843_filename(filename):
    basename = os.path.basename(filename)
    pattern = (
        r'(?P<id>\d+)_.*_Man\d+_'
        r'Cond(?P<cond_a>[A-Z])_Cond(?P<cond_b>[A-Z])_Cond(?P<cond_c>[A-Z])_'
        r'ADC(?P<adc>\d+)_Chirp(?P<chirp>\d+)_SR(?P<sr>\d+)_RE(?P<re>\d+)_FR(?P<fr>\d+)_Gain(?P<gain>\d+)_FS(?P<fs>\d+)_IWR'
    )
    m = re.match(pattern, basename)
    if m:
        params = {k: (int(v) if v.isdigit() else v) for k, v in m.groupdict().items()}
        return params
    else:
        raise ValueError(f"Filename {basename} does not match expected pattern")

# --- 2. Data Decoder Generalized ---
def decode_iwr6843_data(filepath, params, num_rx=4, header_bytes=0):
    num_adc_samples = int(params['adc'])
    num_chirps      = int(params['chirp'])

    with open(filepath, 'rb') as f:
        f.seek(header_bytes)
        raw = np.fromfile(f, dtype=np.int16)

    # Ensure I/Q pairing
    if raw.size % 2 != 0:
        raw = raw[:-1]

    raw = raw.reshape(-1, 2)
    complex_data = raw[:, 0].astype(np.float32) + 1j * raw[:, 1].astype(np.float32)

    samp_pf    = num_rx * num_chirps * num_adc_samples
    num_frames = complex_data.size // samp_pf
    if num_frames == 0:
        print(f"Warning: No frames found for {filepath}. Check ADC/Chirp parameters.")
        return None

    complex_data = complex_data[: num_frames * samp_pf]

    adc = np.empty((num_frames, num_rx, num_chirps, num_adc_samples), dtype=np.complex64)
    for fr in range(num_frames):
        base = fr * samp_pf
        for rx in range(num_rx):
            st = base + rx * (num_chirps * num_adc_samples)
            en = st + (num_chirps * num_adc_samples)
            adc[fr, rx] = complex_data[st:en].reshape(num_chirps, num_adc_samples)
    return adc


# --- 3. RD Spectrogram Generator ---
def generate_rd_spectrogram(adc_tensor):
    """
    adc_tensor: (F, RX, C_chirps, S_samples)
    returns rd: (F, RX, C_doppler, S_range)
    """
    if adc_tensor is None:
        return None
    range_fft = np.fft.fft(adc_tensor, axis=-1)        # range (samples -> bins)
    rd = np.fft.fftshift(np.fft.fft(range_fft, axis=2), axes=2)  # doppler (chirps -> bins)
    return rd

# --- 4. Simple Mask-Based Separation (Spatial Slicing) ---
def mannequin_mask(rd, mannequin_idx, num_mannequins=3):
    """
    Slice RD by RANGE bins into equal contiguous blocks.
    rd: (F, RX, C_doppler, S_range)
    """
    if rd is None:
        return None
    num_range_bins = rd.shape[-1]
    bins_per_man = num_range_bins // num_mannequins
    start = mannequin_idx * bins_per_man
    end   = (mannequin_idx + 1) * bins_per_man if mannequin_idx < num_mannequins - 1 else num_range_bins

    mask = np.zeros_like(rd, dtype=np.float32)
    mask[..., start:end] = 1.0
    return rd * mask

# --- 5. HR/RR Estimation (FFT on slow time) ---
def estimate_hr_rr(rd_masked, params):
    """
    Estimate RR/HR from slow-time (frame) variation of RD energy.

    rd_masked: shape (F, RX, C, S)
    params['fr']: frame period in ms (from filename, e.g., FR40 => 40 ms)
    """
    if rd_masked is None:
        return None, None

    # Collapse RX, Doppler, Range -> 1D time series over frames
    # axes: (F, RX, C, S) -> mean over (1,2,3) => (F,)
    time_series = np.abs(rd_masked).mean(axis=(1, 2, 3))

    if time_series.size < 4:
        return None, None

    # Sample spacing in seconds between frames
    dt = float(params['fr']) / 1000.0

    # One-sided spectrum (non-negative freqs)
    ts_fft = np.fft.rfft(time_series)
    freqs  = np.fft.rfftfreq(time_series.size, d=dt)

    # Physiological bands (Hz)
    rr_band = (0.10, 1.00)   # 6–60 bpm
    hr_band = (1.00, 3.00)   # 60–180 bpm

    rr_mask = (freqs >= rr_band[0]) & (freqs <= rr_band[1])
    hr_mask = (freqs >= hr_band[0]) & (freqs <= hr_band[1])

    RR = None
    HR = None

    if np.any(rr_mask):
        rr_idx  = np.argmax(np.abs(ts_fft[rr_mask]))
        rr_peak = freqs[rr_mask][rr_idx]
        RR = rr_peak * 60.0 if rr_peak > 0 else None

    if np.any(hr_mask):
        hr_idx  = np.argmax(np.abs(ts_fft[hr_mask]))
        hr_peak = freqs[hr_mask][hr_idx]
        HR = hr_peak * 60.0 if hr_peak > 0 else None

    return RR, HR

# --- 6. Metrics ---
def compute_metrics(results):
    if not results:
        return {"RR_MAE": None, "RR_RMSE": None, "HR_MAE": None, "HR_RMSE": None}
    from sklearn.metrics import mean_absolute_error, mean_squared_error
    rr_est = [r['estimated_RR'] for r in results if r['gt_RR'] is not None and r['estimated_RR'] is not None]
    rr_gt  = [r['gt_RR'] for r in results if r['gt_RR'] is not None and r['estimated_RR'] is not None]
    hr_est = [r['estimated_HR'] for r in results if r['gt_HR'] is not None and r['estimated_HR'] is not None]
    hr_gt  = [r['gt_HR'] for r in results if r['gt_HR'] is not None and r['estimated_HR'] is not None]

    metrics = {
        "RR_MAE": mean_absolute_error(rr_gt, rr_est) if rr_gt else None,
        "RR_RMSE": np.sqrt(mean_squared_error(rr_gt, rr_est)) if rr_gt else None,
        "HR_MAE": mean_absolute_error(hr_gt, hr_est) if hr_gt else None,
        "HR_RMSE": np.sqrt(mean_squared_error(hr_gt, hr_est)) if hr_gt else None,
    }
    return metrics

# --- 7. Pipeline Runner ---
def run_pipeline(folder):
    files = [f for f in os.listdir(folder) if f.endswith('.bin') and '_IWR' in f]
    print(f"Found {len(files)} files in {folder}: {files}")
    if not files:
        print("WARNING: No radar files found. Check your folder path and file naming.")
    results = []
    for fname in files:
        fpath = os.path.join(folder, fname)
        try:
            params = parse_iwr6843_filename(fpath)
        except Exception as e:
            print(f"Skipping file {fname}: {e}")
            continue
        adc = decode_iwr6843_data(fpath, params)
        rd = generate_rd_spectrogram(adc)
        for mi in range(3):  # mannequins
            cond_key = f'cond_{chr(97+mi)}'
            cond_code = params[cond_key]
            gt = CONDITION_GT.get(cond_code)
            rd_mask = mannequin_mask(rd, mi)
            RR, HR = estimate_hr_rr(rd_mask, params)
            rr_err = abs(RR - gt['RR']) if (RR is not None and gt and gt.get('RR') is not None) else None
            hr_err = abs(HR - gt['HR']) if (HR is not None and gt and gt.get('HR') is not None) else None
            results.append({
                'file': fname,
                'mannequin': mi,
                'condition': cond_code,
                'condition_name': gt['name'] if gt else None,
                'estimated_RR': RR,
                'estimated_HR': HR,
                'gt_RR': gt['RR'] if gt else None,
                'gt_HR': gt['HR'] if gt else None,
                'RR_err': rr_err,
                'HR_err': hr_err
            })
    metrics = compute_metrics(results)
    print("\n--- Validation Metrics ---")
    for k, v in metrics.items():
        print(f"{k}: {v:.2f}" if v is not None else f"{k}: N/A")
    return results, metrics

# --- Optional: save CSV ---
def save_results_csv(results, out_path="results.csv"):
    import csv
    if not results:
        print("No results to save.")
        return
    keys = results[0].keys()
    with open(out_path, 'w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=keys)
        writer.writeheader()
        writer.writerows(results)

# --- Example usage ---
if __name__ == "__main__":
    folder = "SubsetG"
    res, metrics = run_pipeline(folder)
    save_results_csv(res)
    for r in res:
        print(r)
# Out:
# Found 26 files in SubsetG: ['272_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR_0.bin', '273_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR_0.bin', '259_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR_0.bin', '274_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', '271_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR_0.bin', '254_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR_0.bin', '251_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin', '262_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR_0.bin', '260_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR_0.bin', '258_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR_0.bin', '268_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR_0.bin', '264_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR_0.bin', '250_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', '265_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR_0.bin', '263_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR_0.bin', '270_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR_0.bin', '252_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR_0.bin', '266_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR_0.bin', '256_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR_0.bin', '261_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR_0.bin', '253_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR_0.bin', '267_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR_0.bin', '257_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR_0.bin', '269_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR_0.bin', '255_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR_0.bin', '275_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin']
#
# --- Validation Metrics ---
# RR_MAE: 19.69
# RR_RMSE: 20.73
# HR_MAE: 40.38
# HR_RMSE: 44.21
# {'file': '272_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.677053193857112, 'estimated_HR': 68.77364789672824, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.322946806142888, 'HR_err': 61.226352103271765}
# {'file': '272_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 7.010905853549966, 'estimated_HR': 136.8795904740708, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '272_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.0093478744714, 'estimated_HR': 133.54106387714222, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.9906521255286, 'HR_err': 23.54106387714222}
# {'file': '273_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.688285366842319, 'estimated_HR': 101.23631941629509, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.31171463315768, 'HR_err': 28.76368058370491}
# {'file': '273_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.688285366842319, 'estimated_HR': 140.75800567490882, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '273_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.688285366842319, 'estimated_HR': 94.24402107823268, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.311714633157681, 'HR_err': 15.755978921767323}
# {'file': '259_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.4149560117302045, 'estimated_HR': 82.47800586510263, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.585043988269796, 'HR_err': 47.52199413489737}
# {'file': '259_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 7.331378299120234, 'estimated_HR': 61.400293255131956, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '259_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.4149560117302045, 'estimated_HR': 63.23313782991201, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.585043988269796, 'HR_err': 46.76686217008799}
# {'file': '274_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 15.38118591172537, 'estimated_HR': 74.23094070441373, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 17.618814088274632, 'HR_err': 55.769059295586274}
# {'file': '274_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.0187249219794925, 'estimated_HR': 165.84930896121267, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '274_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.0187249219794925, 'estimated_HR': 131.74320106999554, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.981275078020508, 'HR_err': 21.743201069995536}
# {'file': '271_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.240822320117474, 'estimated_HR': 94.7136563876652, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.759177679882526, 'HR_err': 35.286343612334804}
# {'file': '271_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 7.342143906020558, 'estimated_HR': 135.82966226138032, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '271_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.975036710719531, 'estimated_HR': 61.67400881057269, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.02496328928047, 'HR_err': 48.32599118942731}
# {'file': '254_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.598240469208211, 'estimated_HR': 142.96187683284455, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.40175953079179, 'HR_err': 12.961876832844553}
# {'file': '254_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.048387096774193, 'estimated_HR': 64.33284457478005, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '254_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 7.697947214076246, 'estimated_HR': 118.21847507331377, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 12.302052785923754, 'HR_err': 8.218475073313769}
# {'file': '251_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.578947368421052, 'estimated_HR': 77.30263157894737, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.42105263157895, 'HR_err': 52.69736842105263}
# {'file': '251_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.578947368421052, 'estimated_HR': 60.307017543859644, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '251_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.030701754385965, 'estimated_HR': 63.59649122807017, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.969298245614034, 'HR_err': 46.40350877192983}
# {'file': '262_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.4149560117302045, 'estimated_HR': 76.06304985337243, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.585043988269796, 'HR_err': 53.93695014662757}
# {'file': '262_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.4149560117302045, 'estimated_HR': 76.06304985337243, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '262_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.4149560117302045, 'estimated_HR': 76.06304985337243, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.585043988269796, 'HR_err': 33.93695014662757}
# {'file': '260_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.4149560117302045, 'estimated_HR': 74.23020527859236, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.585043988269796, 'HR_err': 55.769794721407635}
# {'file': '260_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.4149560117302045, 'estimated_HR': 77.89589442815249, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '260_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 7.331378299120234, 'estimated_HR': 71.48093841642228, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 12.668621700879765, 'HR_err': 38.519061583577724}
# {'file': '258_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.443298969072165, 'estimated_HR': 60.75110456553755, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.556701030927833, 'HR_err': 69.24889543446244}
# {'file': '258_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.443298969072165, 'estimated_HR': 84.68335787923418, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '258_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.443298969072165, 'estimated_HR': 65.35346097201769, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.556701030927835, 'HR_err': 44.646539027982314}
# {'file': '268_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.607929515418502, 'estimated_HR': 174.37591776798826, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.3920704845815, 'HR_err': 44.375917767988255}
# {'file': '268_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 14.317180616740087, 'estimated_HR': 61.306901615271656, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '268_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 7.342143906020558, 'estimated_HR': 61.306901615271656, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 12.657856093979442, 'HR_err': 48.693098384728344}
# {'file': '264_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.240822320117474, 'estimated_HR': 87.00440528634361, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.759177679882526, 'HR_err': 42.99559471365639}
# {'file': '264_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.975036710719531, 'estimated_HR': 142.43759177679883, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '264_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 7.342143906020558, 'estimated_HR': 140.96916299559473, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 12.657856093979442, 'HR_err': 30.96916299559473}
# {'file': '250_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.588579795021962, 'estimated_HR': 67.53294289897511, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.411420204978036, 'HR_err': 62.46705710102489}
# {'file': '250_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.039531478770131, 'estimated_HR': 74.12152269399706, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '250_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.588579795021962, 'estimated_HR': 147.6939970717423, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.411420204978038, 'HR_err': 37.6939970717423}
# {'file': '265_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.240822320117474, 'estimated_HR': 61.306901615271656, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.759177679882526, 'HR_err': 68.69309838472834}
# {'file': '265_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.240822320117474, 'estimated_HR': 137.66519823788548, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '265_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.240822320117474, 'estimated_HR': 78.56093979441997, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.759177679882526, 'HR_err': 31.439060205580034}
# {'file': '263_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.4149560117302045, 'estimated_HR': 61.400293255131956, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.585043988269796, 'HR_err': 68.59970674486804}
# {'file': '263_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.4149560117302045, 'estimated_HR': 81.5615835777126, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '263_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.4149560117302045, 'estimated_HR': 73.31378299120233, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.585043988269796, 'HR_err': 36.68621700879767}
# {'file': '270_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.231671554252199, 'estimated_HR': 72.21407624633432, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.7683284457478, 'HR_err': 57.785923753665685}
# {'file': '270_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.231671554252199, 'estimated_HR': 71.11436950146629, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '270_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.231671554252199, 'estimated_HR': 67.44868035190615, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.768328445747802, 'HR_err': 42.55131964809385}
# {'file': '252_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 7.675438596491228, 'estimated_HR': 106.9078947368421, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 25.324561403508774, 'HR_err': 23.092105263157904}
# {'file': '252_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 7.675438596491228, 'estimated_HR': 66.3377192982456, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '252_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.030701754385965, 'estimated_HR': 165.0219298245614, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.969298245614034, 'HR_err': 55.0219298245614}
# {'file': '266_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.240822320117474, 'estimated_HR': 70.48458149779736, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.759177679882526, 'HR_err': 59.515418502202635}
# {'file': '266_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.607929515418502, 'estimated_HR': 171.071953010279, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '266_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 7.342143906020558, 'estimated_HR': 91.40969162995594, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 12.657856093979442, 'HR_err': 18.590308370044056}
# {'file': '256_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.424375917767987, 'estimated_HR': 61.490455212922164, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.57562408223201, 'HR_err': 68.50954478707783}
# {'file': '256_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.424375917767987, 'estimated_HR': 71.58590308370043, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '256_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.424375917767987, 'estimated_HR': 65.16152716593245, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.575624082232013, 'HR_err': 44.838472834067545}
# {'file': '261_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.424375917767987, 'estimated_HR': 72.50367107195301, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.57562408223201, 'HR_err': 57.49632892804699}
# {'file': '261_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.424375917767987, 'estimated_HR': 73.42143906020557, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '261_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.424375917767987, 'estimated_HR': 73.42143906020557, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.575624082232013, 'HR_err': 36.57856093979443}
# {'file': '253_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 8.272058823529413, 'estimated_HR': 106.98529411764707, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 24.727941176470587, 'HR_err': 23.014705882352928}
# {'file': '253_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 7.720588235294119, 'estimated_HR': 60.110294117647065, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '253_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 7.720588235294119, 'estimated_HR': 121.3235294117647, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 12.27941176470588, 'HR_err': 11.323529411764696}
# {'file': '267_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.61764705882353, 'estimated_HR': 79.7794117647059, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.38235294117647, 'HR_err': 50.2205882352941}
# {'file': '267_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.98529411764706, 'estimated_HR': 148.16176470588238, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '267_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.98529411764706, 'estimated_HR': 74.63235294117649, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.01470588235294, 'HR_err': 35.36764705882351}
# {'file': '257_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.424375917767987, 'estimated_HR': 70.66813509544787, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.57562408223201, 'HR_err': 59.331864904552134}
# {'file': '257_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.424375917767987, 'estimated_HR': 60.5726872246696, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '257_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.424375917767987, 'estimated_HR': 81.68135095447869, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.575624082232013, 'HR_err': 28.318649045521312}
# {'file': '269_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 8.076358296622615, 'estimated_HR': 143.1718061674009, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 24.923641703377385, 'HR_err': 13.171806167400888}
# {'file': '269_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 8.076358296622615, 'estimated_HR': 76.3582966226138, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '269_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 7.342143906020558, 'estimated_HR': 65.712187958884, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 12.657856093979442, 'HR_err': 44.287812041116}
# {'file': '255_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.048387096774193, 'estimated_HR': 138.5630498533724, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.951612903225808, 'HR_err': 8.563049853372405}
# {'file': '255_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 6.598240469208211, 'estimated_HR': 152.30938416422285, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '255_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.048387096774193, 'estimated_HR': 102.27272727272727, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.951612903225808, 'HR_err': 7.727272727272734}
# {'file': '275_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 6.333333333333333, 'estimated_HR': 117.33333333333334, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 26.666666666666668, 'HR_err': 12.666666666666657}
# {'file': '275_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 7.0, 'estimated_HR': 108.66666666666667, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '275_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC128_Chirp64_SR1000_RE80_FR40_Gain30_FS30_IWR_0.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 6.333333333333333, 'estimated_HR': 178.33333333333334, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.666666666666668, 'HR_err': 68.33333333333334}

# %%
import os
import numpy as np
import re

# --- GT mapping for conditions ---
CONDITION_GT = {
    'A': {'name': "Healthy rest", 'RR': 14,  'HR': 80},
    'B': {'name': "Healthy sleeping", 'RR': 12, 'HR': 60},
    'C': {'name': "Healthy agitated", 'RR': 20, 'HR': 110},
    'D': {'name': "Apnea", 'RR': 0, 'HR': 80},
    'E': {'name': "Asthma", 'RR': 22, 'HR': 90},
    'F': {'name': "Asthma attack", 'RR': 33, 'HR': 130},
    'G': {'name': "pneumothorax", 'RR': 30, 'HR': 120},
    'H': {'name': "Bradypnea", 'RR': 6, 'HR': 50},
    'I': {'name': "Cardiac arrest", 'RR': 16, 'HR': 160},
    'J': {'name': "ACS Chest Pain", 'RR': 18, 'HR': 104},
    'K': {'name': "Tachynpea Hyperventilation", 'RR': 30, 'HR': 125}
}

# --- 1. Filename Metadata Parser ---
def parse_iwr6843_filename(filename):
    basename = os.path.basename(filename)
    pattern = (
        r'(?P<id>\d+)_.*_Man\d+_'
        r'Cond(?P<cond_a>[A-Z])_Cond(?P<cond_b>[A-Z])_Cond(?P<cond_c>[A-Z])_'
        r'ADC(?P<adc>\d+)_Chirp(?P<chirp>\d+)_SR(?P<sr>\d+)_RE(?P<re>\d+)_FR(?P<fr>\d+)_Gain(?P<gain>\d+)_FS(?P<fs>\d+)_IWR'
    )
    m = re.match(pattern, basename)
    if m:
        params = {k: (int(v) if v.isdigit() else v) for k, v in m.groupdict().items()}
        return params
    else:
        raise ValueError(f"Filename {basename} does not match expected pattern")

# --- 2. Data Decoder Generalized ---
def decode_iwr6843_data(filepath, params, num_rx=4, header_bytes=0):
    num_adc_samples = int(params['adc'])
    num_chirps      = int(params['chirp'])

    with open(filepath, 'rb') as f:
        f.seek(header_bytes)
        raw = np.fromfile(f, dtype=np.int16)

    # Ensure I/Q pairing
    if raw.size % 2 != 0:
        raw = raw[:-1]

    raw = raw.reshape(-1, 2)
    complex_data = raw[:, 0].astype(np.float32) + 1j * raw[:, 1].astype(np.float32)

    samp_pf    = num_rx * num_chirps * num_adc_samples
    num_frames = complex_data.size // samp_pf
    if num_frames == 0:
        print(f"Warning: No frames found for {filepath}. Check ADC/Chirp parameters.")
        return None

    complex_data = complex_data[: num_frames * samp_pf]

    adc = np.empty((num_frames, num_rx, num_chirps, num_adc_samples), dtype=np.complex64)
    for fr in range(num_frames):
        base = fr * samp_pf
        for rx in range(num_rx):
            st = base + rx * (num_chirps * num_adc_samples)
            en = st + (num_chirps * num_adc_samples)
            adc[fr, rx] = complex_data[st:en].reshape(num_chirps, num_adc_samples)
    return adc

# --- 5. HR/RR Estimation (FFT on slow time) ---
def estimate_hr_rr(rd_masked, params):
    """


    return RR, HR"""""

# --- 6. Metrics ---
def compute_metrics(results):
    if not results:
        return {"RR_MAE": None, "RR_RMSE": None, "HR_MAE": None, "HR_RMSE": None}
    from sklearn.metrics import mean_absolute_error, mean_squared_error
    rr_est = [r['estimated_RR'] for r in results if r['gt_RR'] is not None and r['estimated_RR'] is not None]
    rr_gt  = [r['gt_RR'] for r in results if r['gt_RR'] is not None and r['estimated_RR'] is not None]
    hr_est = [r['estimated_HR'] for r in results if r['gt_HR'] is not None and r['estimated_HR'] is not None]
    hr_gt  = [r['gt_HR'] for r in results if r['gt_HR'] is not None and r['estimated_HR'] is not None]

    metrics = {
        "RR_MAE": mean_absolute_error(rr_gt, rr_est) if rr_gt else None,
        "RR_RMSE": np.sqrt(mean_squared_error(rr_gt, rr_est)) if rr_gt else None,
        "HR_MAE": mean_absolute_error(hr_gt, hr_est) if hr_gt else None,
        "HR_RMSE": np.sqrt(mean_squared_error(hr_gt, hr_est)) if hr_gt else None,
    }
    return metrics

# --- 7. Pipeline Runner ---
def run_pipeline(folder):
    files = [f for f in os.listdir(folder) if f.endswith('.bin') and '_IWR' in f]
    print(f"Found {len(files)} files in {folder}: {files}")
    if not files:
        print("WARNING: No radar files found. Check your folder path and file naming.")
    results = []
    for fname in files:
        fpath = os.path.join(folder, fname)
        try:
            params = parse_iwr6843_filename(fpath)
        except Exception as e:
            print(f"Skipping file {fname}: {e}")
            continue
        adc = decode_iwr6843_data(fpath, params)
        rd = generate_rd_spectrogram(adc)
        for mi in range(3):  # mannequins
            cond_key = f'cond_{chr(97+mi)}'
            cond_code = params[cond_key]
            gt = CONDITION_GT.get(cond_code)
            rd_mask = mannequin_mask(rd, mi)
            RR, HR = estimate_hr_rr(rd_mask, params)
            rr_err = abs(RR - gt['RR']) if (RR is not None and gt and gt.get('RR') is not None) else None
            hr_err = abs(HR - gt['HR']) if (HR is not None and gt and gt.get('HR') is not None) else None
            results.append({
                'file': fname,
                'mannequin': mi,
                'condition': cond_code,
                'condition_name': gt['name'] if gt else None,
                'estimated_RR': RR,
                'estimated_HR': HR,
                'gt_RR': gt['RR'] if gt else None,
                'gt_HR': gt['HR'] if gt else None,
                'RR_err': rr_err,
                'HR_err': hr_err
            })
    metrics = compute_metrics(results)
    print("\n--- Validation Metrics ---")
    for k, v in metrics.items():
        print(f"{k}: {v:.2f}" if v is not None else f"{k}: N/A")
    return results, metrics


# --- Example usage ---
if __name__ == "__main__":
    folder = "SubsetJ"
    res, metrics = run_pipeline(folder)
    save_results_csv(res)
    for r in res:
        print(r)
# Out:
# Found 25 files in SubsetJ: ['333_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR.bin', '329_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR.bin', '339_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR.bin', '340_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR.bin', '323_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR.bin', '344_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR.bin', '325_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR.bin', '341_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR.bin', '330_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR.bin', '328_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR.bin', '345_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', '343_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR.bin', '322_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR.bin', '337_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR.bin', '335_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR.bin', '331_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR.bin', '327_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR.bin', '332_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR.bin', '342_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR.bin', '336_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR.bin', '321_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', '334_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR.bin', '324_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR.bin', '338_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR.bin', '326_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR.bin']
#
# --- Validation Metrics ---
# RR_MAE: 9.70
# RR_RMSE: 12.30
# HR_MAE: 36.97
# HR_RMSE: 40.49
# {'file': '333_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 20.380434782608692, 'estimated_HR': 101.90217391304347, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 12.619565217391308, 'HR_err': 28.09782608695653}
# {'file': '333_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 20.380434782608692, 'estimated_HR': 95.1086956521739, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '333_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 20.380434782608692, 'estimated_HR': 95.1086956521739, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.3804347826086918, 'HR_err': 14.891304347826093}
# {'file': '329_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 20.380434782608692, 'estimated_HR': 74.7282608695652, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 12.619565217391308, 'HR_err': 55.271739130434796}
# {'file': '329_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 20.380434782608692, 'estimated_HR': 74.7282608695652, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '329_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 20.380434782608692, 'estimated_HR': 74.7282608695652, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.3804347826086918, 'HR_err': 35.271739130434796}
# {'file': '339_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 35.32608695652174, 'estimated_HR': 70.65217391304348, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 2.326086956521742, 'HR_err': 59.347826086956516}
# {'file': '339_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 35.32608695652174, 'estimated_HR': 89.67391304347828, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '339_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 35.32608695652174, 'estimated_HR': 70.65217391304348, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 15.326086956521742, 'HR_err': 39.347826086956516}
# {'file': '340_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 10.869565217391306, 'estimated_HR': 97.82608695652175, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 22.130434782608695, 'HR_err': 32.17391304347825}
# {'file': '340_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 35.32608695652174, 'estimated_HR': 70.65217391304348, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '340_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 35.32608695652174, 'estimated_HR': 70.65217391304348, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 15.326086956521742, 'HR_err': 39.347826086956516}
# {'file': '323_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 15.957446808510639, 'estimated_HR': 63.829787234042556, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 17.04255319148936, 'HR_err': 66.17021276595744}
# {'file': '323_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 19.9468085106383, 'estimated_HR': 63.829787234042556, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '323_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 19.9468085106383, 'estimated_HR': 71.80851063829786, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.05319148936170137, 'HR_err': 38.19148936170214}
# {'file': '344_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 19.176136363636367, 'estimated_HR': 70.3125, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 13.823863636363633, 'HR_err': 59.6875}
# {'file': '344_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 19.176136363636367, 'estimated_HR': 70.3125, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '344_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 19.176136363636367, 'estimated_HR': 70.3125, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.8238636363636331, 'HR_err': 39.6875}
# {'file': '325_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 36.68478260869565, 'estimated_HR': 69.29347826086956, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 3.6847826086956488, 'HR_err': 60.70652173913044}
# {'file': '325_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 16.304347826086957, 'estimated_HR': 69.29347826086956, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '325_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 16.304347826086957, 'estimated_HR': 69.29347826086956, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 3.695652173913043, 'HR_err': 40.70652173913044}
# {'file': '341_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 38.88888888888889, 'estimated_HR': 83.33333333333334, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 5.888888888888893, 'HR_err': 46.66666666666666}
# {'file': '341_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 38.88888888888889, 'estimated_HR': 83.33333333333334, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '341_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain40_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 38.88888888888889, 'estimated_HR': 83.33333333333334, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 18.888888888888893, 'HR_err': 26.666666666666657}
# {'file': '330_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 20.380434782608692, 'estimated_HR': 61.14130434782608, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 12.619565217391308, 'HR_err': 68.85869565217392}
# {'file': '330_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 20.380434782608692, 'estimated_HR': 61.14130434782608, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '330_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 20.380434782608692, 'estimated_HR': 61.14130434782608, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.3804347826086918, 'HR_err': 48.85869565217392}
# {'file': '328_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 20.380434782608692, 'estimated_HR': 108.69565217391303, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 12.619565217391308, 'HR_err': 21.304347826086968}
# {'file': '328_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 13.586956521739129, 'estimated_HR': 108.69565217391303, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '328_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain40_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 20.380434782608692, 'estimated_HR': 108.69565217391303, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.3804347826086918, 'HR_err': 1.3043478260869676}
# {'file': '345_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 19.176136363636367, 'estimated_HR': 70.3125, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 13.823863636363633, 'HR_err': 59.6875}
# {'file': '345_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 19.176136363636367, 'estimated_HR': 70.3125, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '345_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp64_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 19.176136363636367, 'estimated_HR': 70.3125, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.8238636363636331, 'HR_err': 39.6875}
# {'file': '343_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 33.333333333333336, 'estimated_HR': 83.33333333333334, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 0.3333333333333357, 'HR_err': 46.66666666666666}
# {'file': '343_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 33.333333333333336, 'estimated_HR': 83.33333333333334, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '343_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 33.333333333333336, 'estimated_HR': 83.33333333333334, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.333333333333336, 'HR_err': 26.666666666666657}
# {'file': '322_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 15.957446808510639, 'estimated_HR': 67.81914893617021, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 17.04255319148936, 'HR_err': 62.18085106382979}
# {'file': '322_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 19.9468085106383, 'estimated_HR': 75.79787234042553, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '322_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain30_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 15.957446808510639, 'estimated_HR': 67.81914893617021, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 4.042553191489361, 'HR_err': 42.18085106382979}
# {'file': '337_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 36.111111111111114, 'estimated_HR': 91.66666666666667, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 3.1111111111111143, 'HR_err': 38.33333333333333}
# {'file': '337_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 36.111111111111114, 'estimated_HR': 91.66666666666667, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '337_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 36.111111111111114, 'estimated_HR': 91.66666666666667, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 16.111111111111114, 'HR_err': 18.33333333333333}
# {'file': '335_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 34.722222222222214, 'estimated_HR': 97.22222222222221, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 1.7222222222222143, 'HR_err': 32.777777777777786}
# {'file': '335_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 34.722222222222214, 'estimated_HR': 97.22222222222221, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '335_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 34.722222222222214, 'estimated_HR': 97.22222222222221, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 14.722222222222214, 'HR_err': 12.777777777777786}
# {'file': '331_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 20.380434782608692, 'estimated_HR': 74.7282608695652, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 12.619565217391308, 'HR_err': 55.271739130434796}
# {'file': '331_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 20.380434782608692, 'estimated_HR': 74.7282608695652, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '331_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR24_Gain30_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 20.380434782608692, 'estimated_HR': 74.7282608695652, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.3804347826086918, 'HR_err': 35.271739130434796}
# {'file': '327_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 20.380434782608695, 'estimated_HR': 101.90217391304347, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 12.619565217391305, 'HR_err': 28.09782608695653}
# {'file': '327_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 20.380434782608695, 'estimated_HR': 101.90217391304347, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '327_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 20.380434782608695, 'estimated_HR': 101.90217391304347, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 0.38043478260869534, 'HR_err': 8.09782608695653}
# {'file': '332_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 33.96739130434782, 'estimated_HR': 115.4891304347826, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 0.9673913043478208, 'HR_err': 14.510869565217405}
# {'file': '332_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 33.96739130434782, 'estimated_HR': 81.52173913043477, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '332_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain40_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 33.96739130434782, 'estimated_HR': 81.52173913043477, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 13.96739130434782, 'HR_err': 28.478260869565233}
# {'file': '342_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 22.222222222222225, 'estimated_HR': 97.22222222222223, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 10.777777777777775, 'HR_err': 32.77777777777777}
# {'file': '342_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 36.111111111111114, 'estimated_HR': 77.77777777777779, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '342_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR60_Gain30_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 36.111111111111114, 'estimated_HR': 77.77777777777779, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 16.111111111111114, 'HR_err': 32.222222222222214}
# {'file': '336_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 19.444444444444446, 'estimated_HR': 100.0, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 13.555555555555554, 'HR_err': 30.0}
# {'file': '336_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 36.111111111111114, 'estimated_HR': 100.0, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '336_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain40_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 36.111111111111114, 'estimated_HR': 100.0, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 16.111111111111114, 'HR_err': 10.0}
# {'file': '321_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 15.957446808510639, 'estimated_HR': 67.81914893617021, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 17.04255319148936, 'HR_err': 62.18085106382979}
# {'file': '321_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 15.957446808510639, 'estimated_HR': 67.81914893617021, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '321_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR40_Gain40_FS30_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 15.957446808510639, 'estimated_HR': 67.81914893617021, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 4.042553191489361, 'HR_err': 42.18085106382979}
# {'file': '334_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 13.888888888888888, 'estimated_HR': 76.38888888888887, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 19.111111111111114, 'HR_err': 53.61111111111113}
# {'file': '334_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 34.722222222222214, 'estimated_HR': 90.27777777777777, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '334_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR24_Gain30_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 34.722222222222214, 'estimated_HR': 90.27777777777777, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 14.722222222222214, 'HR_err': 19.72222222222223}
# {'file': '324_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 36.68478260869565, 'estimated_HR': 89.67391304347825, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 3.6847826086956488, 'HR_err': 40.32608695652175}
# {'file': '324_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 36.68478260869565, 'estimated_HR': 89.67391304347825, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '324_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain40_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 36.68478260869565, 'estimated_HR': 89.67391304347825, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 16.68478260869565, 'HR_err': 20.32608695652175}
# {'file': '338_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 16.666666666666668, 'estimated_HR': 86.11111111111111, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 16.333333333333332, 'HR_err': 43.888888888888886}
# {'file': '338_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 19.444444444444446, 'estimated_HR': 86.11111111111111, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '338_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE80_FR60_Gain30_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 16.666666666666668, 'estimated_HR': 97.22222222222223, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 3.333333333333332, 'HR_err': 12.777777777777771}
# {'file': '326_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR.bin', 'mannequin': 0, 'condition': 'F', 'condition_name': 'Asthma attack', 'estimated_RR': 36.68478260869565, 'estimated_HR': 81.52173913043478, 'gt_RR': 33, 'gt_HR': 130, 'RR_err': 3.6847826086956488, 'HR_err': 48.47826086956522}
# {'file': '326_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR.bin', 'mannequin': 1, 'condition': 'M', 'condition_name': None, 'estimated_RR': 52.98913043478261, 'estimated_HR': 93.75, 'gt_RR': None, 'gt_HR': None, 'RR_err': None, 'HR_err': None}
# {'file': '326_TopFront_4m_0deg_Man3_CondF_CondM_CondC_ADC64_Chirp128_SR1000_RE60_FR40_Gain30_FS60_IWR.bin', 'mannequin': 2, 'condition': 'C', 'condition_name': 'Healthy agitated', 'estimated_RR': 52.98913043478261, 'estimated_HR': 81.52173913043478, 'gt_RR': 20, 'gt_HR': 110, 'RR_err': 32.98913043478261, 'HR_err': 28.47826086956522}
